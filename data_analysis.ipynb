# %% [markdown]
# **1.Data Loading**

# %%
import pandas as pd
import numpy as np

# %%
df_Apr = pd.read_csv('CRIME_REVIEW_FOR_THE_MONTH_OF_APRIL_2025.csv')
df_Feb = pd.read_csv('CRIME_REVIEW_FOR_THE_MONTH_OF_FEBRUARY_2025_0.csv')
df_Mar = pd.read_csv('CRIME_REVIEW_FOR_THE_MONTH_OF_MARCH_2025_0.csv')

# %%
df_Apr.head()
# Out:
#   Heads of Crime                           Major Heads  \
# 0  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
# 1  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
# 2  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
# 3  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
# 4  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
#
#                            Minor Heads  \
# 0                             For gain
# 1                Over Property Dispute
# 2  Due to Personal Vendetta or enemity
# 3               Due to Sexual jealousy
# 4                 For dowry by burning
#
#    During the current year upto the end of month under review  \
# 0                                                 15
# 1                                                  9
# 2                                                 10
# 3                                                 12
# 4                                                  1
#
#    During the corresponding month of previous year  During the previous month  \
# 0                                                3                          4
# 1                                                5                          1
# 2                                                3                          1
# 3                                                2                          2
# 4                                                0                          0
#
#    During the current month  Month
# 0                         3  April
# 1                         1  April
# 2                         1  April
# 3                         4  April
# 4                         0  April

# %%
df_Feb.head()
# Out:
#    SL.NO. Heads of Crime                           Major Heads  \
# 0       1  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
# 1       2  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
# 2       3  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
# 3       4  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
# 4       5  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
#
#                            Minor Heads  \
# 0                             For gain
# 1                Over Property Dispute
# 2  Due to Personal Vendetta or enemity
# 3               Due to Sexual jealousy
# 4                 For dowry by burning
#
#    During the current year upto the end of month under review  \
# 0                                                7.0
# 1                                                6.0
# 2                                                7.0
# 3                                                6.0
# 4                                                1.0
#
#    During the corresponding month of previous year  During the previous month  \
# 0                                              2.0                        4.0
# 1                                              6.0                        2.0
# 2                                              1.0                        2.0
# 3                                              1.0                        2.0
# 4                                              0.0                        1.0
#
#    During the current month     Month
# 0                       3.0  February
# 1                       4.0  February
# 2                       5.0  February
# 3                       4.0  February
# 4                       0.0  February

# %%
df_Mar.head()
# Out:
#    Sl.No. Heads of Crime                           Major Heads  \
# 0       1  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
# 1       2  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
# 2       3  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
# 3       4  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
# 4       5  A - IPC Crime  Murder (Sec.302/303 IPC/103,104 BNS)
#
#                            Minor Heads  \
# 0                             For gain
# 1                Over Property Dispute
# 2  Due to Personal Vendetta or enemity
# 3               Due to Sexual jealousy
# 4                 For dowry by burning
#
#    During the current year upto the end of month under review  \
# 0                                                  9
# 1                                                  8
# 2                                                  9
# 3                                                  7
# 4                                                  1
#
#    During the corresponding month of previous year  During the previous month  \
# 0                                                2                          3
# 1                                                0                          5
# 2                                                2                          6
# 3                                                1                          4
# 4                                                0                          0
#
#    During the current month  Month
# 0                         2  March
# 1                         1  March
# 2                         1  March
# 3                         1  March
# 4                         0  March

# %%
df_Apr.isna().sum()
# Out:
# Heads of Crime                                                 0
# Major Heads                                                    0
# Minor Heads                                                   70
# During the current year upto the end of month under review     0
# During the corresponding month of previous year                0
# During the previous month                                      0
# During the current month                                       0
# Month                                                          0
# dtype: int64

# %%
df_Mar.isna().sum()
# Out:
# Sl.No.                                                         0
# Heads of Crime                                                 0
# Major Heads                                                    0
# Minor Heads                                                   71
# During the current year upto the end of month under review     0
# During the corresponding month of previous year                0
# During the previous month                                      0
# During the current month                                       0
# Month                                                          0
# dtype: int64

# %%
df_Apr.isna().sum()
# Out:
# Heads of Crime                                                 0
# Major Heads                                                    0
# Minor Heads                                                   70
# During the current year upto the end of month under review     0
# During the corresponding month of previous year                0
# During the previous month                                      0
# During the current month                                       0
# Month                                                          0
# dtype: int64

# %%
df_Apr['Minor Heads'].fillna('Not Important',inplace =True)
df_Feb['Minor Heads'].fillna('Not Important',inplace =True)
df_Mar['Minor Heads'].fillna('Not Important',inplace =True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_15948\4013824296.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_Apr['Minor Heads'].fillna('Not Important',inplace =True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_15948\4013824296.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_Feb['Minor Heads'].fillna('Not Important',inplace =True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_15948\4013824296.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_Mar['Minor Heads'].fillna('Not Important',inplace =True)

# %%
df_Mar.isna().sum()
# Out:
# Sl.No.                                                        0
# Heads of Crime                                                0
# Major Heads                                                   0
# Minor Heads                                                   0
# During the current year upto the end of month under review    0
# During the corresponding month of previous year               0
# During the previous month                                     0
# During the current month                                      0
# Month                                                         0
# dtype: int64

# %%
df_Apr.isna().sum()
# Out:
# Heads of Crime                                                0
# Major Heads                                                   0
# Minor Heads                                                   0
# During the current year upto the end of month under review    0
# During the corresponding month of previous year               0
# During the previous month                                     0
# During the current month                                      0
# Month                                                         0
# dtype: int64

# %%
df_Feb['During the current year upto the end of month under review'].fillna(0,inplace=True)
df_Feb['During the corresponding month of previous year'].fillna(0,inplace=True)
df_Feb['During the current month'].fillna(0,inplace=True)
df_Feb['During the previous month'].fillna(0,inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_15948\46979688.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_Feb['During the current year upto the end of month under review'].fillna(0,inplace=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_15948\46979688.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_Feb['During the corresponding month of previous year'].fillna(0,inplace=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_15948\46979688.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_Feb['During the current month'].fillna(0,inplace=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_15948\46979688.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_Feb['During the previous month'].fillna(0,inplace=True)

# %%
df_Feb.isna().sum()
# Out:
# SL.NO.                                                        0
# Heads of Crime                                                0
# Major Heads                                                   0
# Minor Heads                                                   0
# During the current year upto the end of month under review    0
# During the corresponding month of previous year               0
# During the previous month                                     0
# During the current month                                      0
# Month                                                         0
# dtype: int64

# %%
df_all = pd.concat([df_Feb,df_Mar,df_Apr],ignore_index=True)

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2190 entries, 0 to 2189
# Data columns (total 10 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   SL.NO.                                                      731 non-null    float64
#  1   Heads of Crime                                              2190 non-null   object
#  2   Major Heads                                                 2190 non-null   object
#  3   Minor Heads                                                 2190 non-null   object
#  4   During the current year upto the end of month under review  2190 non-null   float64
#  5   During the corresponding month of previous year             2190 non-null   float64
#  6   During the previous month                                   2190 non-null   float64
#  7   During the current month                                    2190 non-null   float64
#  8   Month                                                       2190 non-null   object
#  9   Sl.No.                                                      730 non-null    float64
# dtypes: float64(6), object(4)
# memory usage: 171.2+ KB

# %%
df_all.drop(columns=['SL.NO.','Sl.No.'],inplace=True)

# %%
df_all.to_csv("crime_data.csv")

# %%
df_all
# Out:
#                                          Heads of Crime  \
# 0                                         A - IPC Crime
# 1                                         A - IPC Crime
# 2                                         A - IPC Crime
# 3                                         A - IPC Crime
# 4                                         A - IPC Crime
# ...                                                 ...
# 2185      E. CRIME AGAINST SCHEDULED CASTES /TRIBES ...
# 2186      E. CRIME AGAINST SCHEDULED CASTES /TRIBES ...
# 2187      E. CRIME AGAINST SCHEDULED CASTES /TRIBES ...
# 2188      E. CRIME AGAINST SCHEDULED CASTES /TRIBES ...
# 2189      E. CRIME AGAINST SCHEDULED CASTES /TRIBES ...
#
#                                             Major Heads  \
# 0                  Murder (Sec.302/303 IPC/103,104 BNS)
# 1                  Murder (Sec.302/303 IPC/103,104 BNS)
# 2                  Murder (Sec.302/303 IPC/103,104 BNS)
# 3                  Murder (Sec.302/303 IPC/103,104 BNS)
# 4                  Murder (Sec.302/303 IPC/103,104 BNS)
# ...                                                 ...
# 2185                                             Murder
# 2186                                               Rape
# 2187                                         Kidnapping
# 2188  Offences under the Protection of Civil Rights ...
# 2189  Offences under the SC & ST  (prevention of Atr...
#
#                               Minor Heads  \
# 0                                For gain
# 1                   Over Property Dispute
# 2     Due to Personal Vendetta or enemity
# 3                  Due to Sexual jealousy
# 4                    For dowry by burning
# ...                                   ...
# 2185                        Not Important
# 2186                        Not Important
# 2187                        Not Important
# 2188                        Not Important
# 2189                        Not Important
#
#       During the current year upto the end of month under review  \
# 0                                                   7.0
# 1                                                   6.0
# 2                                                   7.0
# 3                                                   6.0
# 4                                                   1.0
# ...                                                 ...
# 2185                                               28.0
# 2186                                               51.0
# 2187                                               51.0
# 2188                                                0.0
# 2189                                              616.0
#
#       During the corresponding month of previous year  \
# 0                                                 2.0
# 1                                                 6.0
# 2                                                 1.0
# 3                                                 1.0
# 4                                                 0.0
# ...                                               ...
# 2185                                             12.0
# 2186                                             12.0
# 2187                                             10.0
# 2188                                              0.0
# 2189                                            157.0
#
#       During the previous month  During the current month     Month
# 0                           4.0                       3.0  February
# 1                           2.0                       4.0  February
# 2                           2.0                       5.0  February
# 3                           2.0                       4.0  February
# 4                           1.0                       0.0  February
# ...                         ...                       ...       ...
# 2185                        6.0                       4.0     April
# 2186                       16.0                      15.0     April
# 2187                       19.0                       4.0     April
# 2188                        0.0                       0.0     April
# 2189                      161.0                     163.0     April
#
# [2190 rows x 8 columns]

# %%
df_g = df_all.groupby(['Heads of Crime','Major Heads'])['During the current month'].sum()

# %%
df_g.values
# Out:
# array([3.000e+01, 1.400e+01, 0.000e+00, 4.810e+02, 3.900e+01, 7.000e+00,
#        1.550e+02, 6.500e+01, 4.000e+00, 0.000e+00, 1.600e+01, 8.760e+02,
#        6.600e+01, 2.450e+02, 9.140e+02, 0.000e+00, 4.312e+03, 1.433e+03,
#        7.000e+01, 4.000e+00, 1.700e+02, 7.000e+00, 7.350e+02, 3.000e+00,
#        6.510e+02, 7.200e+02, 3.500e+01, 1.700e+01, 4.800e+01, 7.400e+01,
#        7.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 3.400e+01, 9.000e+00,
#        1.000e+00, 8.000e+00, 1.090e+02, 1.550e+02, 1.000e+00, 1.490e+02,
#        4.000e+00, 3.000e+00, 1.000e+00, 6.000e+00, 1.000e+00, 1.280e+02,
#        1.285e+03, 1.190e+02, 1.472e+03, 2.729e+03, 8.054e+03, 3.220e+02,
#        1.072e+03, 3.000e+00, 3.180e+02, 0.000e+00, 0.000e+00, 3.600e+01,
#        1.000e+01, 4.000e+00, 3.000e+00, 1.000e+00, 5.500e+01, 7.710e+02,
#        2.520e+02, 0.000e+00, 8.610e+02, 2.560e+02, 0.000e+00, 1.000e+00,
#        2.030e+02, 5.244e+03, 0.000e+00, 1.130e+02, 8.200e+01, 1.000e+00,
#        3.000e+00, 4.000e+01, 2.000e+00, 3.200e+01, 2.000e+00, 8.000e+00,
#        3.000e+00, 1.100e+01, 1.000e+00, 7.000e+00, 1.060e+02, 0.000e+00,
#        0.000e+00, 3.000e+00, 1.730e+02, 3.700e+01, 1.800e+01, 3.840e+02,
#        4.060e+02, 0.000e+00, 3.432e+03, 2.300e+01, 0.000e+00, 1.400e+01,
#        1.000e+00, 0.000e+00, 6.400e+01, 5.000e+00, 0.000e+00, 3.100e+01,
#        1.599e+03, 2.112e+03, 7.800e+01, 4.120e+02, 1.760e+02, 3.241e+03,
#        1.365e+03, 0.000e+00, 0.000e+00, 2.000e+00, 9.050e+02, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 3.300e+01, 0.000e+00, 1.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 5.640e+02, 0.000e+00, 4.600e+01, 0.000e+00,
#        9.000e+00, 2.630e+02, 7.200e+02, 1.052e+03, 1.000e+00, 3.300e+01,
#        6.400e+01, 0.000e+00, 1.280e+02, 2.700e+01, 0.000e+00, 4.000e+00,
#        9.700e+01, 3.800e+01, 7.000e+00, 1.472e+03, 1.000e+00, 2.520e+02,
#        1.000e+01, 7.000e+00, 1.700e+01, 1.000e+00, 1.000e+00, 5.100e+01,
#        1.185e+03, 1.000e+00, 9.050e+02, 0.000e+00, 8.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 7.470e+02, 4.500e+01, 0.000e+00,
#        0.000e+00, 1.000e+00])

# %%
df_g.index[0:].unique()
# Out:
# MultiIndex([('    E. CRIME AGAINST SCHEDULED CASTES /TRIBES BY NON SCs/STs \n', ...),
#             ('    E. CRIME AGAINST SCHEDULED CASTES /TRIBES BY NON SCs/STs \n', ...),
#             ('    E. CRIME AGAINST SCHEDULED CASTES /TRIBES BY NON SCs/STs \n', ...),
#             ('    E. CRIME AGAINST SCHEDULED CASTES /TRIBES BY NON SCs/STs \n', ...),
#             ('    E. CRIME AGAINST SCHEDULED CASTES /TRIBES BY NON SCs/STs \n', ...),
#             (                                                  'A - IPC Crime', ...),
#             (                                                  'A - IPC Crime', ...),
#             (                                                  'A - IPC Crime', ...),
#             (                                                  'A - IPC Crime', ...),
#             (                                                  'A - IPC Crime', ...),
#             ...
#             (                                       'D.CRIME AGAINST CHILDREN', ...),
#             (                                       'D.CRIME AGAINST CHILDREN', ...),
#             (                                       'D.CRIME AGAINST CHILDREN', ...),
#             (                                       'D.CRIME AGAINST CHILDREN', ...),
#             (                                       'D.CRIME AGAINST CHILDREN', ...),
#             (                                       'D.CRIME AGAINST CHILDREN', ...),
#             (                                       'D.CRIME AGAINST CHILDREN', ...),
#             (                                       'D.CRIME AGAINST CHILDREN', ...),
#             (                                       'D.CRIME AGAINST CHILDREN', ...),
#             (                                       'D.CRIME AGAINST CHILDREN', ...)],
#            names=['Heads of Crime', 'Major Heads'], length=176)
